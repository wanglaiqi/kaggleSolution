# %%
import urllib
import urllib2
import re
import thread
import time

# %%
"""
request = urllib2.Request("http://www.baidu.com")
response = urllib2.urlopen(request)
print response.read()
"""

#http://python.jobbole.com/81359/
import urllib
import urllib2
page = 1
url = 'http://www.qiushibaike.com/hot/page/'+ str(page)
user_agent = 'Mozilla/4.0 (compatible; MSIE 5.5; Windows NT)'
headers = { 'User-Agent' : user_agent }
try:
    request = urllib2.Request(url,headers = headers)
    response = urllib2.urlopen(request)
    content = response.read().decode('utf-8')
    pattern = re.compile('<div.*?class="author.*?>.*?<a.*?</a>.*?<a.*?>(.*?)</a>.*?<div.*?class'+
                     '="content".*?title="(.*?)">(.*?)</div>(.*?)<div class="stats.*?class="number">(.*?)</i>',re.S)
    items = re.findall(pattern,content)
    for item in items:
        print item[0],item[1],item[2],item[3],item[4]
except urllib2.URLError, e:
    if hasattr(e,"code"):
        print e.code
    if hasattr(e,"reason"):
        print e.reason
# Out:
# <h2>叫我圣龙哥！</h2>
# 分享到微信" rel="nofollow 微信</a>
# <a class="share-qq" data-type="qq" title="分享到QQ" rel="nofollow">QQ</a>
# <a class="share-qzone" data-type="qzone" title="分享到QQ空间" rel="nofollow">QQ空间</a>
# <a class="share-weibo" data-type="weibo" title="分享到微博" rel="nofollow">微博</a>
#
# <div class="single-clear"></div>
#
#
#
#
# </div>
#
#
#
#
#
#
#
#
# <div class="article block untagged mb15" id='qiushi_tag_117979974'>
#
# <div class="author clearfix">
# <a href="/users/13145907/" target="_blank" rel="nofollow">
# <img src="http://pic.qiushibaike.com/system/avtnew/1314/13145907/medium/20140731141650.jpg" alt="一个小时的好汉"/>
# </a>
# <a href="/users/13145907/" target="_blank" title="一个小时的好汉">
# <h2>一个小时的好汉</h2>
# </a>
# <div class="articleGender manIcon">28</div>
# </div>
#
#
#
# <a href="/article/117979974" target="_blank" class='contentHerf' >
# <div class="content">
#
#
#
# <span>今天给儿子去买小笼包，旁边有个拾荒的老大爷手里就拿着一块钱问，包子怎么卖，老板说五块一笼，抬头看老大爷愣了一下，老大爷转身缓缓的走了，就听见老板在后面喊，老大爷，小笼包五块一笼，这里的包子一块钱三个，老板从别的大笼里面，夹出三个热腾腾的大肉包，当时有点莫名的感动！老板你是个好人</span>
#
#
# </div>
# </a>
#
#
#
#
#
# 18741
#
# <h2>宿迁首席鉴黄师</h2>
# 分享到微信" rel="nofollow 微信</a>
# <a class="share-qq" data-type="qq" title="分享到QQ" rel="nofollow">QQ</a>
# <a class="share-qzone" data-type="qzone" title="分享到QQ空间" rel="nofollow">QQ空间</a>
# <a class="share-weibo" data-type="weibo" title="分享到微博" rel="nofollow">微博</a>
#
# <div class="single-clear"></div>
#
#
#
#
# </div>
#
#
#
#
#
#
#
#
# <div class="article block untagged mb15" id='qiushi_tag_117992054'>
#
# <div class="author clearfix">
# <a href="/users/31167196/" target="_blank" rel="nofollow">
# <img src="http://pic.qiushibaike.com/system/avtnew/3116/31167196/medium/2016111420381970.JPEG" alt="皇朝~~墨染"/>
# </a>
# <a href="/users/31167196/" target="_blank" title="皇朝~~墨染">
# <h2>皇朝~~墨染</h2>
# </a>
# <div class="articleGender womenIcon">99</div>
# </div>
#
#
#
# <a href="/article/117992054" target="_blank" class='contentHerf' >
# <div class="content">
#
#
#
# <span>以前有个傻子，充话费冲错了，冲到我手机号了。<br/>给我打电话求我冲回去，我想无功不受禄，就答应冲回去了。<br/>结果充话费的过程，我也冲错了…</span>
#
#
# </div>
# </a>
#
#
#
#
#
# 5322
#
# <h2>南宫二姐</h2>
# 分享到微信" rel="nofollow 微信</a>
# <a class="share-qq" data-type="qq" title="分享到QQ" rel="nofollow">QQ</a>
# <a class="share-qzone" data-type="qzone" title="分享到QQ空间" rel="nofollow">QQ空间</a>
# <a class="share-weibo" data-type="weibo" title="分享到微博" rel="nofollow">微博</a>
#
# <div class="single-clear"></div>
#
#
#
#
# <a href="/article/117985121" class='indexGodCmt' onclick="_hmt.push(['_trackEvent','web_list_god','chick'])" rel="nofollow" target='_blank' >
# <div class="cmtMain">
# <span class="cmt-god" ></span>
#
# <span class="cmt-name">小野猫aaad</span>
#
# <div class="main-text">
# ：哈哈 有趣啊。。。。
# <div class="likenum">
# <img src="http://static.qiushibaike.com/images/newarticle/like@1.5.png?v=7f35e15cccadf187957112f7ba0537fc" />
#
#
# 34
#
# </div>
# </div>
# </div>
# </a>
#
#
#
# </div>
#
#
#
#
#
#
#
#
# <div class="article block untagged mb15" id='qiushi_tag_117993868'>
#
# <div class="author clearfix">
# <a href="/users/31187946/" target="_blank" rel="nofollow">
# <img src="http://pic.qiushibaike.com/system/avtnew/3118/31187946/medium/20160522052159.jpg" alt="依然范特西:"/>
# </a>
# <a href="/users/31187946/" target="_blank" title="依然范特西:">
# <h2>依然范特西:</h2>
# </a>
# <div class="articleGender manIcon">90</div>
# </div>
#
#
#
# <a href="/article/117993868" target="_blank" class='contentHerf' >
# <div class="content">
#
#
#
# <span>高考时候隔壁班的同学将课本全部扔到楼下，表示自己终于得到了释放，获得了自由。我也带领我们班将书也全部抛下，班主任发现了一巴掌拍我头上骂道:你一个高二的扔哪门子书啊？</span>
#
#
# </div>
# </a>
#
#
#
#
#
# 1974
#
# <h2>三地</h2>
# 分享到微信" rel="nofollow 微信</a>
# <a class="share-qq" data-type="qq" title="分享到QQ" rel="nofollow">QQ</a>
# <a class="share-qzone" data-type="qzone" title="分享到QQ空间" rel="nofollow">QQ空间</a>
# <a class="share-weibo" data-type="weibo" title="分享到微博" rel="nofollow">微博</a>
#
# <div class="single-clear"></div>
#
#
#
#
# </div>
#
#
#
#
#
#
#
#
# <div class="article block untagged mb15" id='qiushi_tag_117993215'>
#
# <div class="author clearfix">
# <a href="/users/16933887/" target="_blank" rel="nofollow">
# <img src="http://pic.qiushibaike.com/system/avtnew/1693/16933887/medium/2016102823061063.JPEG" alt="大杨么么哒"/>
# </a>
# <a href="/users/16933887/" target="_blank" title="大杨么么哒">
# <h2>大杨么么哒</h2>
# </a>
# <div class="articleGender womenIcon">22</div>
# </div>
#
#
#
# <a href="/article/117993215" target="_blank" class='contentHerf' >
# <div class="content">
#
#
#
# <span>爸爸：我死了以后，请把我的骨灰撒到大海。妈妈：死了也不让人省心，从这去大海多远啊！爸爸：那把我放坐便器冲掉吧，我自己找路去大海！#死了都想自驾游！#</span>
#
#
# </div>
# </a>
#
#
#
#
#
# 3167
#
# <h2>熊和熊猫的故事</h2>
# 分享到微信" rel="nofollow 微信</a>
# <a class="share-qq" data-type="qq" title="分享到QQ" rel="nofollow">QQ</a>
# <a class="share-qzone" data-type="qzone" title="分享到QQ空间" rel="nofollow">QQ空间</a>
# <a class="share-weibo" data-type="weibo" title="分享到微博" rel="nofollow">微博</a>
#
# <div class="single-clear"></div>
#
#
#
#
# <a href="/article/117993513" class='indexGodCmt' onclick="_hmt.push(['_trackEvent','web_list_god','chick'])" rel="nofollow" target='_blank' >
# <div class="cmtMain">
# <span class="cmt-god" ></span>
#
# <span class="cmt-name">冷酒暖烟</span>
#
# <div class="main-text">
# ：人才啊，强烈要求你爸去外交部上班。
# <div class="likenum">
# <img src="http://static.qiushibaike.com/images/newarticle/like@1.5.png?v=7f35e15cccadf187957112f7ba0537fc" />
#
#
# 58
#
# </div>
# </div>
# </div>
# </a>
#
#
#
# </div>
#
#
#
#
#
#
#
#
# <div class="article block untagged mb15" id='qiushi_tag_117994868'>
#
# <div class="author clearfix">
# <a href="/users/32792236/" target="_blank" rel="nofollow">
# <img src="http://pic.qiushibaike.com/system/avtnew/3279/32792236/medium/2016101123084426.JPEG" alt="讨喜～"/>
# </a>
# <a href="/users/32792236/" target="_blank" title="讨喜～">
# <h2>讨喜～</h2>
# </a>
# <div class="articleGender womenIcon">20</div>
# </div>
#
#
#
# <a href="/article/117994868" target="_blank" class='contentHerf' >
# <div class="content">
#
#
#
# <span>家里有一人高大的布熊，主要用来防老妈，在晚上想出去玩却又不被允许的情况下，我会洋装去睡觉，然后把娃娃放床上，被子一盖，妥妥的，老爸掩护我出门，屡试不爽。今天老妈发脾气，一问才知道，老爸乘老妈睡着后也用这招，偷溜出去打牌，半夜一摸，软绵绵的，差点没吓出心脏病……</span>
#
#
# </div>
# </a>
#
#
#
#
#
# 1648
#
# <h2>终极X匿名用户</h2>
# 分享到微信" rel="nofollow 微信</a>
# <a class="share-qq" data-type="qq" title="分享到QQ" rel="nofollow">QQ</a>
# <a class="share-qzone" data-type="qzone" title="分享到QQ空间" rel="nofollow">QQ空间</a>
# <a class="share-weibo" data-type="weibo" title="分享到微博" rel="nofollow">微博</a>
#
# <div class="single-clear"></div>
#
#
#
#
# <a href="/article/117993859" class='indexGodCmt' onclick="_hmt.push(['_trackEvent','web_list_god','chick'])" rel="nofollow" target='_blank' >
# <div class="cmtMain">
# <span class="cmt-god" ></span>
#
# <span class="cmt-name">shanyan0532</span>
#
# <div class="main-text">
# ：当晚就被拉去陪客户，顿感五雷轰顶。第二天醒来才知道，机智的发现，原来喝醉了屁股疼啊!
# <div class="likenum">
# <img src="http://static.qiushibaike.com/images/newarticle/like@1.5.png?v=7f35e15cccadf187957112f7ba0537fc" />
#
#
# 106
#
# </div>
# </div>
# </div>
# </a>
#
#
#
# </div>
#
#
#
#
#
#
#
#
# <div class="article block untagged mb15" id='qiushi_tag_117981100'>
#
# <div class="author clearfix">
# <a href="/users/10653903/" target="_blank" rel="nofollow">
# <img src="http://pic.qiushibaike.com/system/avtnew/1065/10653903/medium/2016110419042099.JPEG" alt="青楼满座う墨染"/>
# </a>
# <a href="/users/10653903/" target="_blank" title="青楼满座う墨染">
# <h2>青楼满座う墨染</h2>
# </a>
# <div class="articleGender womenIcon">21</div>
# </div>
#
#
#
# <a href="/article/117981100" target="_blank" class='contentHerf' >
# <div class="content">
#
#
#
# <span>今天有个男的粉我，我回粉了，他问我有没有男朋友，我说没有，我以为他要说他可以吗的，结果人家说，哈哈哈，我就知道你没有，长的那么难看，我特码……</span>
#
#
# </div>
# </a>
#
#
#
#
#
# 8671
#
# <h2>苹果99</h2>
# 分享到微信" rel="nofollow 微信</a>
# <a class="share-qq" data-type="qq" title="分享到QQ" rel="nofollow">QQ</a>
# <a class="share-qzone" data-type="qzone" title="分享到QQ空间" rel="nofollow">QQ空间</a>
# <a class="share-weibo" data-type="weibo" title="分享到微博" rel="nofollow">微博</a>
#
# <div class="single-clear"></div>
#
#
#
#
# </div>
#
#
#
#
#
#
#
#
# <div class="article block untagged mb15" id='qiushi_tag_117993680'>
#
# <div class="author clearfix">
# <a href="/users/31017736/" target="_blank" rel="nofollow">
# <img src="http://pic.qiushibaike.com/system/avtnew/3101/31017736/medium/20160124002717.jpg" alt="918疯狂英子"/>
# </a>
# <a href="/users/31017736/" target="_blank" title="918疯狂英子">
# <h2>918疯狂英子</h2>
# </a>
# <div class="articleGender womenIcon">35</div>
# </div>
#
#
#
# <a href="/article/117993680" target="_blank" class='contentHerf' >
# <div class="content">
#
#
#
# <span>有个快递小哥给我送了一整个月的快递，有次催我下楼拿的时候我想先洗个头，就跟小哥说，哥我洗个头就来。没想到小哥在电话那头吐了一口烟说，别洗了，我们是那种不洗头也能见面的关系…………</span>
#
#
# </div>
# </a>
#
#
#
#
#
# 2740
#
# <h2>流浪的猫*</h2>
# 分享到微信" rel="nofollow 微信</a>
# <a class="share-qq" data-type="qq" title="分享到QQ" rel="nofollow">QQ</a>
# <a class="share-qzone" data-type="qzone" title="分享到QQ空间" rel="nofollow">QQ空间</a>
# <a class="share-weibo" data-type="weibo" title="分享到微博" rel="nofollow">微博</a>
#
# <div class="single-clear"></div>
#
#
#
#
# <a href="/article/117985696" class='indexGodCmt' onclick="_hmt.push(['_trackEvent','web_list_god','chick'])" rel="nofollow" target='_blank' >
# <div class="cmtMain">
# <span class="cmt-god" ></span>
#
# <span class="cmt-name">斜阳烟柳</span>
#
# <div class="main-text">
# ：女儿都打成这样，老公还能幸免吗？不禁为楼主感到担心
# <div class="likenum">
# <img src="http://static.qiushibaike.com/images/newarticle/like@1.5.png?v=7f35e15cccadf187957112f7ba0537fc" />
#
#
# 48
#
# </div>
# </div>
# </div>
# </a>
#
#
#
# </div>
#
#
#
#
#
#
#
#
# <div class="article block untagged mb15" id='qiushi_tag_117984983'>
#
# <div class="author clearfix">
# <a href="/users/25190748/" target="_blank" rel="nofollow">
# <img src="http://pic.qiushibaike.com/system/avtnew/2519/25190748/medium/2016110812295293.JPEG" alt="二女子、"/>
# </a>
# <a href="/users/25190748/" target="_blank" title="二女子、">
# <h2>二女子、</h2>
# </a>
# <div class="articleGender womenIcon">26</div>
# </div>
#
#
#
# <a href="/article/117984983" target="_blank" class='contentHerf' >
# <div class="content">
#
#
#
# <span>跟同事去食堂吃饭，看着同事的菜明显比我的要多，而且钱是一样的，我就去找打饭的阿姨理论，本来我已经做好吵架的准备了，阿姨一句话就给我浇灭了，我看你那么瘦，吃的肯定没她多，所以给你打的少…</span>
#
#
# </div>
# </a>
#
#
#
#
#
# 8161
#
# <h2>斜阳烟柳</h2>
# 分享到微信" rel="nofollow 微信</a>
# <a class="share-qq" data-type="qq" title="分享到QQ" rel="nofollow">QQ</a>
# <a class="share-qzone" data-type="qzone" title="分享到QQ空间" rel="nofollow">QQ空间</a>
# <a class="share-weibo" data-type="weibo" title="分享到微博" rel="nofollow">微博</a>
#
# <div class="single-clear"></div>
#
#
#
#
# <a href="/article/117991934" class='indexGodCmt' onclick="_hmt.push(['_trackEvent','web_list_god','chick'])" rel="nofollow" target='_blank' >
# <div class="cmtMain">
# <span class="cmt-god" ></span>
#
# <span class="cmt-name">(糗名昭著)~小翔</span>
#
# <div class="main-text">
# ：看来，射嘴里也不安全了
# <div class="likenum">
# <img src="http://static.qiushibaike.com/images/newarticle/like@1.5.png?v=7f35e15cccadf187957112f7ba0537fc" />
#
#
# 94
#
# </div>
# </div>
# </div>
# </a>
#
#
#
# </div>
#
#
#
#
#
#
#
#
# <div class="article block untagged mb15" id='qiushi_tag_117978753'>
#
# <div class="author clearfix">
# <a href="/users/25580412/" target="_blank" rel="nofollow">
# <img src="http://pic.qiushibaike.com/system/avtnew/2558/25580412/medium/2016111509143818.JPEG" alt="古有诗词歌赋"/>
# </a>
# <a href="/users/25580412/" target="_blank" title="古有诗词歌赋">
# <h2>古有诗词歌赋</h2>
# </a>
# <div class="articleGender womenIcon">21</div>
# </div>
#
#
#
# <a href="/article/117978753" target="_blank" class='contentHerf' >
# <div class="content">
#
#
#
# <span>肯德基吃饭。一个孩子问他 妈妈: “妈妈我怎么来的？”<br/>他 妈妈 : “你爸上传我下载的。”<br/>我一口可乐就这样喷出来了。。。</span>
#
#
# </div>
# </a>
#
#
#
#
#
# 6220
#
# <h2>流浪悳草莓</h2>
# 分享到微信" rel="nofollow 微信</a>
# <a class="share-qq" data-type="qq" title="分享到QQ" rel="nofollow">QQ</a>
# <a class="share-qzone" data-type="qzone" title="分享到QQ空间" rel="nofollow">QQ空间</a>
# <a class="share-weibo" data-type="weibo" title="分享到微博" rel="nofollow">微博</a>
#
# <div class="single-clear"></div>
#
#
#
#
# <a href="/article/117992369" class='indexGodCmt' onclick="_hmt.push(['_trackEvent','web_list_god','chick'])" rel="nofollow" target='_blank' >
# <div class="cmtMain">
# <span class="cmt-god" ></span>
#
# <span class="cmt-name">醉酒舞剑砍疯子※</span>
#
# <div class="main-text">
# ：我想躺楼主被窝听楼主讲荤段子
# <div class="likenum">
# <img src="http://static.qiushibaike.com/images/newarticle/like@1.5.png?v=7f35e15cccadf187957112f7ba0537fc" />
#
#
# 28
#
# </div>
# </div>
# </div>
# </a>
#
#
#
# </div>
#
#
#
#
#
#
#
#
# <div class="article block untagged mb15" id='qiushi_tag_117985737'>
#
# <div class="author clearfix">
# <a href="/users/29154820/" target="_blank" rel="nofollow">
# <img src="http://pic.qiushibaike.com/system/avtnew/2915/29154820/medium/20161028211738.jpg" alt="南宮，柱流年"/>
# </a>
# <a href="/users/29154820/" target="_blank" title="南宮，柱流年">
# <h2>南宮，柱流年</h2>
# </a>
# <div class="articleGender manIcon">26</div>
# </div>
#
#
#
# <a href="/article/117985737" target="_blank" class='contentHerf' >
# <div class="content">
#
#
#
# <span>高中时候，有个女生趴桌子上睡觉，老师喊她，XXX  你是昨天没有睡好吗？她迷迷糊糊的回了句  “老师，我感觉欲火焚身！”<br/>全班沸腾了啊，，，<br/>后来老师去摸了摸她的头，真发骚了，重感冒！</span>
#
#
# </div>
# </a>
#
#
#
#
#
# 5520
